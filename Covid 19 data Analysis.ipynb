# %% [markdown]
# # Covid 19 Data Analysis notebook

# %% [markdown]
# ## Import the modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('modules are imported.')
# Out:
# modules are imported.

# %% [markdown]
# ## Import Covid 19 Dataset

# %%
covid_dataset_csv = pd.read_csv('Datasets/covid19_Confirmed_dataset.csv')
covid_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/24/20  \
# 0        0        0        0        0        0        0  ...    29640
# ...

# %% [markdown]
# # Import Total Death Dataset

# %%
death_dataset_csv = pd.read_csv('Datasets/time_series_covid19_deaths_global.csv')
death_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/24/20  \
# 0        0        0        0        0        0        0  ...      639
# ...

# %% [markdown]
# ## Delete and marge

# %%
death_dataset_csv.drop(['Lat','Long'], axis=1,inplace=True)
death_dataset_marged = death_dataset_csv.groupby('Country/Region').sum()
death_dataset_marged.head(15)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        0        0
# Austria                    0        0        0        0        0        0
# Azerbaijan                 0        0        0        0        0        0
# ...

# %% [markdown]
# # Import total recovare Dataset

# %%
recover_dataset_csv = pd.read_csv('Datasets/time_series_covid19_recovered_global.csv')
recover_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/24/20  \
# 0        0        0        0        0        0        0  ...     9869
# ...

# %% [markdown]
# ## Delete and marge

# %%
recover_dataset_csv.drop(['Lat','Long'], axis=1,inplace=True)
recover_dataset_marged = recover_dataset_csv.groupby('Country/Region').sum()
recover_dataset_marged.head(15)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        0        0
# Austria                    0        0        0        0        0        0
# Azerbaijan                 0        0        0        0        0        0
# ...

# %% [markdown]
# ## Shape of the Dataframe

# %%
covid_dataset_csv.shape
# Out:
# (266, 168)

# %% [markdown]
# ## Delete useless column

# %%
covid_dataset_csv.drop(['Lat','Long'], axis=1,inplace=True) #axis 0 is row, 
#without inplace=True it will copy the dataset and make anather one

# %%
covid_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  6/24/20  \
# 0        0        0        0        0        0        0  ...    29640
# ...

# %% [markdown]
# ## Marge the row by the Country without state

# %%
covid_dataset_marged = covid_dataset_csv.groupby('Country/Region').sum()

# %%
covid_dataset_marged.head(15)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
# Azerbaijan                 0        0        0        0        0        0
# ...

# %%
covid_dataset_marged.shape
# Out:
# (188, 164)

# %% [markdown]
# ## Visualize infected data by Country

# %%
covid_dataset_marged.loc["Bangladesh"].plot()
covid_dataset_marged.loc["China"].plot()
covid_dataset_marged.loc["Pakistan"].plot()
plt.xlabel("Date")
plt.ylabel("Infected")
plt.legend()
plt.title("Infected ratio")
plt.savefig("Infected.png")

# %% [markdown]
# # Visualize Death Data by country

# %%
death_dataset_marged.loc["Bangladesh"].plot()
death_dataset_marged.loc["China"].plot()
death_dataset_marged.loc["Pakistan"].plot()
plt.legend()
plt.title("Death ratio")
plt.xlabel("Date")
plt.ylabel("Death")
plt.savefig("death.png")

# %% [markdown]
# ## Visualize recovered Data by country

# %%
recover_dataset_marged.loc["Bangladesh"].plot()
recover_dataset_marged.loc["China"].plot()
recover_dataset_marged.loc["Pakistan"].plot()
plt.legend()
plt.title("recover ratio")
plt.xlabel("Date")
plt.ylabel("Recover")
plt.savefig("recover.png")

# %% [markdown]
# ## Calculating a good measure

# %%
covid_dataset_marged.loc["Bangladesh"].plot()

# %%
covid_dataset_marged.loc["Bangladesh"][:10].plot()

# %% [markdown]
# ## Calculate and plot the first derivative of the carve

# %%
covid_dataset_marged.loc["Bangladesh"].diff().plot()

# %% [markdown]
# ## Find maximum infaction rate in a country

# %%
covid_dataset_marged.loc["Bangladesh"].diff().max()
# Out:
# 4019.0

# %%
covid_dataset_marged.loc["India"].diff().max()
# Out:
# 22771.0

# %%
covid_dataset_marged.loc["Pakistan"].diff().max()
# Out:
# 12073.0

# %% [markdown]
# ## Find max infaction rate for all country

# %%
countries = list(covid_dataset_marged.index)
max_infaction_rate = []

for c in countries:
    max_infaction_rate.append(covid_dataset_marged.loc[c].diff().max())

covid_dataset_marged["max_infaction_rate"] = max_infaction_rate

# %%
covid_dataset_marged.head(15)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
# Azerbaijan                 0        0        0        0        0        0
# ...

# %% [markdown]
# ## Create new Dataframe for needed column

# %%
covid_data = pd.DataFrame(covid_dataset_marged['max_infaction_rate'])

# %%
covid_data.head()
# Out:
#                 max_infaction_rate
# Country/Region
# Afghanistan                  915.0
# Albania                       90.0
# Algeria                      413.0
# Andorra                       79.0
# Angola                        47.0

# %% [markdown]
# # Import World happiness Dataset

# %%
happiness_report = pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
happiness_report.shape
# Out:
# (156, 9)

# %% [markdown]
# ## Drop useless column

# %%
useless_cols = ['Overall rank', 'Score', 'Generosity','Perceptions of corruption']

# %%
happiness_report.drop(useless_cols, axis=1,inplace=True)
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ## Change primary key as country

# %%
happiness_report.set_index("Country or region", inplace=True)

# %%
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# # Join this two Dataset:

# %% [markdown]
# ## Covid dataset:

# %%
covid_data.head()
# Out:
#                 max_infaction_rate
# Country/Region
# Afghanistan                  915.0
# Albania                       90.0
# Algeria                      413.0
# Andorra                       79.0
# Angola                        47.0

# %%
covid_data.shape
# Out:
# (188, 1)

# %% [markdown]
# ## World happiness report Dataset:

# %%
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report.shape
# Out:
# (156, 4)

# %% [markdown]
# ## Inner join

# %%
data = covid_data.join(happiness_report, how="inner")
data.head()
# Out:
#              max_infaction_rate  GDP per capita  Social support  \
# Afghanistan               915.0           0.350           0.517
# Albania                    90.0           0.947           0.848
# Algeria                   413.0           1.002           1.160
# Argentina                2886.0           1.092           1.432
# Armenia                   771.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# # Correlation matrix

# %%
data.corr()
# Out:
#                               max_infaction_rate  GDP per capita  \
# max_infaction_rate                      1.000000        0.165464
# GDP per capita                          0.165464        1.000000
# Social support                          0.132474        0.757521
# Healthy life expectancy                 0.152477        0.859431
# Freedom to make life choices            0.051024        0.394799
#
#                               Social support  Healthy life expectancy  \
# max_infaction_rate                  0.132474                 0.152477
# GDP per capita                      0.757521                 0.859431
# Social support                      1.000000                 0.751632
# Healthy life expectancy             0.751632                 1.000000
# Freedom to make life choices        0.456317                 0.423146
#
#                               Freedom to make life choices
# max_infaction_rate                                0.051024
# ...

# %% [markdown]
# # Visualize the result

# %%
data.head()
# Out:
#              max_infaction_rate  GDP per capita  Social support  \
# Afghanistan               915.0           0.350           0.517
# Albania                    90.0           0.947           0.848
# Algeria                   413.0           1.002           1.160
# Argentina                2886.0           1.092           1.432
# Armenia                   771.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ## Plot GDP vs max infaction rate

# %%
x = data["GDP per capita"]
y = data["max_infaction_rate"]
#sns.scatterplot(x,y)
sns.scatterplot(x, np.log(y)) #using seaborn - log scalling method

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max_infaction_rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max_infaction_rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max_infaction_rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
